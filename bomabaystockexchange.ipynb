# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("BSE-BOM531276.csv")

# %%
df.head()
# Out:
#          Date   Open   High    Low  Close     WAP  No. of Shares  \
# 0  2015-11-09  120.0  129.1  120.0  129.0  126.04        32430.0
# 1  2015-11-06  122.6  125.9  122.6  123.0  122.76          467.0
# 2  2015-11-05  123.0  123.9  123.0  123.9  123.49         5583.0
# 3  2015-10-30  122.0  122.0  121.1  121.1  121.18          110.0
# 4  2015-10-29  121.1  121.1  121.1  121.1  121.10         1000.0
#
#    No. of Trades  Total Turnover  Deliverable Quantity  \
# 0           39.0       4087421.0               32430.0
# 1            7.0         57331.0                 467.0
# 2           11.0        689455.0                5583.0
# 3            2.0         13330.0                 110.0
# 4            1.0        121100.0                1000.0
#
#    % Deli. Qty to Traded Qty  Spread H-L  Spread C-O
# 0                      100.0         9.1         9.0
# 1                      100.0         3.3         0.4
# 2                      100.0         0.9         0.9
# ...

# %%
df
# Out:
#             Date    Open    High     Low   Close         WAP  No. of Shares  \
# 0     2015-11-09  120.00  129.10  120.00  129.00  126.040000        32430.0
# 1     2015-11-06  122.60  125.90  122.60  123.00  122.760000          467.0
# 2     2015-11-05  123.00  123.90  123.00  123.90  123.490000         5583.0
# 3     2015-10-30  122.00  122.00  121.10  121.10  121.180000          110.0
# 4     2015-10-29  121.10  121.10  121.10  121.10  121.100000         1000.0
# 5     2015-10-27  121.20  121.90  120.10  121.80  121.070000         6725.0
# 6     2015-10-26  121.40  122.90  121.40  121.40  121.440000         1694.0
# 7     2015-10-21  121.20  121.20  121.20  121.20  121.200000          250.0
# 8     2015-10-20  121.00  121.00  121.00  121.00  121.000000          500.0
# 9     2015-10-19  121.00  123.00  119.10  123.00  121.370000          973.0
# 10    2015-10-16  120.80  122.50  120.80  121.00  121.210000          349.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
df.plot(y='Open')
plt.show()

# %%
df.plot(y='High')
plt.show()

# %%
df.plot(y='No. of Shares')
plt.show()
