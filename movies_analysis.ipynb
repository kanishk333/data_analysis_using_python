# %%
import pandas as pd

# %%
df=pd.read_csv('myfolder.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                              Title    Year  \
# 0           0  Intolerance: Love's Struggle Throughout the Ages   1916.0
# 1           1                    Over the Hill to the Poorhouse   1920.0
# 2           2                                    The Big Parade   1925.0
# 3           3                                        Metropolis   1927.0
# 4           4                                     Pandora's Box   1929.0
#
#                 Genres Language  Country Content Rating  Duration  \
# 0    Drama|History|War      NaN      USA      Not Rated     123.0
# 1          Crime|Drama      NaN      USA            NaN     110.0
# 2    Drama|Romance|War      NaN      USA      Not Rated     151.0
# 3         Drama|Sci-Fi   German  Germany      Not Rated     145.0
# 4  Crime|Drama|Romance   German  Germany      Not Rated     110.0
#
#    Aspect Ratio     Budget  ...  Facebook Likes - Actor 1  \
# 0          1.33   385907.0  ...                     436.0
# ...

# %%
df.shape
# Out:
# (5042, 26)

# %%
df.dtypes
# Out:
# Unnamed: 0                       int64
# Title                           object
# Year                           float64
# Genres                          object
# Language                        object
# Country                         object
# Content Rating                  object
# Duration                       float64
# Aspect Ratio                   float64
# Budget                         float64
# Gross Earnings                 float64
# Director                        object
# Actor 1                         object
# Actor 2                         object
# Actor 3                         object
# Facebook Likes - Director      float64
# Facebook Likes - Actor 1       float64
# Facebook Likes - Actor 2       float64
# Facebook Likes - Actor 3       float64
# Facebook Likes - cast Total      int64
# Facebook likes - Movie           int64
# Facenumber in posters          float64
# User Votes                       int64
# Reviews by Users               float64
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0         Year     Duration  Aspect Ratio        Budget  \
# count  5042.000000  4935.000000  5028.000000   4714.000000  4.551000e+03
# mean    869.498017  2002.470517   107.201074      2.220403  3.975262e+07
# std     535.354866    12.474599    25.197441      1.385113  2.061149e+08
# min       0.000000  1916.000000     7.000000      1.180000  2.180000e+02
# 25%     420.000000  1999.000000    93.000000      1.850000  6.000000e+06
# 50%     840.000000  2005.000000   103.000000      2.350000  2.000000e+07
# 75%    1260.000000  2011.000000   118.000000      2.350000  4.500000e+07
# max    2099.000000  2016.000000   511.000000     16.000000  1.221550e+10
#
#        Gross Earnings  Facebook Likes - Director  Facebook Likes - Actor 1  \
# count    4.159000e+03                4938.000000               5035.000000
# mean     4.846841e+07                 686.621709               6561.323932
# std      6.845299e+07                2813.602405              15021.977635
# ...

# %%
df.Genres.value_counts()
# Out:
# Drama                                                   236
# Comedy                                                  209
# Comedy|Drama                                            191
# Comedy|Drama|Romance                                    187
# Comedy|Romance                                          158
# Drama|Romance                                           152
# Crime|Drama|Thriller                                    101
# Horror                                                   71
# Action|Crime|Drama|Thriller                              68
# Action|Crime|Thriller                                    65
# Drama|Thriller                                           64
# Crime|Drama                                              63
# Horror|Thriller                                          56
# Crime|Drama|Mystery|Thriller                             55
# Action|Adventure|Sci-Fi                                  51
# Comedy|Crime                                             51
# ...

# %%
df.Genres.value_counts().head(3)
# Out:
# Drama           236
# Comedy          209
# Comedy|Drama    191
# Name: Genres, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df.Genres.value_counts()[:3].plot(kind='bar',cmap='autumn')
plt.show()

# %%
df[df['Duration']>200]
# Out:
#       Unnamed: 0                          Title    Year  \
# 18            18            Gone with the Wind   1939.0
# 61            61                 Seven Samurai   1954.0
# 83            83            Lawrence of Arabia   1962.0
# 91            91                     Cleopatra   1963.0
# 112          112  The Greatest Story Ever Told   1965.0
# 158          158                     Woodstock   1970.0
# 192          192        The Godfather: Part II   1974.0
# 248          248                Apocalypse Now   1979.0
# 268          268                 Heaven's Gate   1980.0
# 287          287                      Das Boot   1981.0
# 334          334                        Gandhi   1982.0
# 385          385   Once Upon a Time in America   1984.0
# 481          481              The Last Emperor   1987.0
# 555          555            Dances with Wolves   1990.0
# 593          593                           JFK   1991.0
# 630          630                     Malcolm X   1992.0
# ...

# %%
df[df['Duration']>200].shape
# Out:
# (36, 26)

# %%
m=df.sort_values(by='Duration',ascending=False).index[:3]

# %% [markdown]
# m

# %%
m
# Out:
# Int64Index([5032, 4947, 649], dtype='int64')

# %%
df.iloc[m,[1,7]]
# Out:
#                      Title  Duration
# 5032  Trapped                  511.0
# 4947   Carlos                  334.0
# 649   Blood In, Blood Out      330.0

# %%
df[df.Title.str.startswith('Once')]
# Out:
#       Unnamed: 0                                              Title    Year  \
# 133          133                      Once Upon a Time in the West   1968.0
# 385          385                       Once Upon a Time in America   1984.0
# 1996         658                        Once Upon a Time in Mexico   2003.0
# 2640        1302  Once in a Lifetime: The Extraordinary Story of...  2006.0
# 2857        1519                                              Once   2007.0
# 4239         801                        Once Upon a Time in Queens   2013.0
#
#                      Genres Language  Country Content Rating  Duration  \
# 133                 Western  English    Italy          PG-13     145.0
# 385             Crime|Drama  English    Italy              R     251.0
# 1996  Action|Crime|Thriller  English      USA              R     102.0
# 2640      Documentary|Sport  English       UK          PG-13      97.0
# 2857    Drama|Music|Romance  English  Ireland              R      85.0
# ...

# %%
df.columns=df.columns.str.strip().str.replace(' ','_')

# %%
df
# Out:
#       Unnamed:_0                                              Title    Year  \
# 0              0  Intolerance: Love's Struggle Throughout the Ages   1916.0
# 1              1                    Over the Hill to the Poorhouse   1920.0
# 2              2                                    The Big Parade   1925.0
# 3              3                                        Metropolis   1927.0
# 4              4                                     Pandora's Box   1929.0
# 5              5                               The Broadway Melody   1929.0
# 6              6                                     Hell's Angels   1930.0
# 7              7                                A Farewell to Arms   1932.0
# 8              8                                       42nd Street   1933.0
# 9              9                                She Done Him Wrong   1933.0
# 10            10                             It Happened One Night   1934.0
# ...

# %%
df[df.Content_Rating=='R']
# Out:
#       Unnamed:_0                                              Title    Year  \
# 75            75                                            Psycho   1960.0
# 98            98                              A Fistful of Dollars   1964.0
# 134          134                                   Rosemary's Baby   1968.0
# 140          140                               Mississippi Mermaid   1969.0
# 145          145                                    The Wild Bunch   1969.0
# 149          149                                          Catch-22   1970.0
# 150          150                            Cotton Comes to Harlem   1970.0
# 153          153                         The Ballad of Cable Hogue   1970.0
# 154          154                                    The Conformist   1970.0
# 158          158                                         Woodstock   1970.0
# 164          164                 Sweet Sweetback's Baadasssss Song   1971.0
# ...

# %%
df[df.Gross_Earnings.isnull()]
# Out:
#       Unnamed:_0                                              Title    Year  \
# 0              0  Intolerance: Love's Struggle Throughout the Ages   1916.0
# 2              2                                    The Big Parade   1925.0
# 6              6                                     Hell's Angels   1930.0
# 7              7                                A Farewell to Arms   1932.0
# 9              9                                She Done Him Wrong   1933.0
# 10            10                             It Happened One Night   1934.0
# 13            13                   The Charge of the Light Brigade   1936.0
# 15            15                             The Prisoner of Zenda   1937.0
# 16            16                          Alexander's Ragtime Band   1938.0
# 17            17                        You Can't Take It with You   1938.0
# 19            19                      Mr. Smith Goes to Washington   1939.0
# ...

# %%
df[df.Gross_Earnings.isnull()].shape
# Out:
# (883, 26)

# %%
df[(df.Country=='India')&(df.Actor_1=='Shah Rukh Khan')]
# Out:
#       Unnamed:_0                    Title    Year                    Genres  \
# 2275         937              Veer-Zaara   2004.0     Drama|Musical|Romance
# 2610        1272  Kabhi Alvida Naa Kehna   2006.0                     Drama
# 3553         115         My Name Is Khan   2010.0  Adventure|Drama|Thriller
# 3969         531        Jab Tak Hai Jaan   2012.0             Drama|Romance
#
#      Language Country Content_Rating  Duration  Aspect_Ratio       Budget  \
# 2275    Hindi   India            NaN     192.0          2.35    7000000.0
# 2610    Hindi   India              R     193.0          2.35  700000000.0
# 3553    Hindi   India          PG-13     128.0          2.35   12000000.0
# 3969    Hindi   India      Not Rated     176.0          2.35    7217600.0
#
#       ...  Facebook_Likes_-_Actor_1 Facebook_Likes_-_Actor_2  \
# 2275  ...                    8000.0                    860.0
# 2610  ...                    8000.0                   1000.0
# ...

# %%
df[df.IMDB_Score>7]
# Out:
#       Unnamed:_0                                              Title    Year  \
# 0              0  Intolerance: Love's Struggle Throughout the Ages   1916.0
# 2              2                                    The Big Parade   1925.0
# 3              3                                        Metropolis   1927.0
# 4              4                                     Pandora's Box   1929.0
# 6              6                                     Hell's Angels   1930.0
# 8              8                                       42nd Street   1933.0
# 10            10                             It Happened One Night   1934.0
# 11            11                                           Top Hat   1935.0
# 12            12                                      Modern Times   1936.0
# 13            13                   The Charge of the Light Brigade   1936.0
# 14            14                   Snow White and the Seven Dwarfs   1937.0
# ...

# %%
df.add_prefix('movies_')
# Out:
#       movies_Unnamed:_0                                       movies_Title  \
# 0                     0  Intolerance: Love's Struggle Throughout the Ages
# 1                     1                    Over the Hill to the Poorhouse
# 2                     2                                    The Big Parade
# 3                     3                                        Metropolis
# 4                     4                                     Pandora's Box
# 5                     5                               The Broadway Melody
# 6                     6                                     Hell's Angels
# 7                     7                                A Farewell to Arms
# 8                     8                                       42nd Street
# 9                     9                                She Done Him Wrong
# 10                   10                             It Happened One Night
# 11                   11                                           Top Hat
# ...
